# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Importing necessary libraries

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline 

from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR
from sklearn.model_selection import train_test_split

# %%
# calling data from the directory Dataset in my drive folder.
# https://www.kaggle.com/kashnitsky/mlcourse?select=video_games_sales.csv
games = pd.read_csv('drive/MyDrive/Dataset/video_games_sales.csv')

games.head(3)
# Out:
#                 Name Platform  Year_of_Release  ... User_Count Developer  Rating
# 0         Wii Sports      Wii           2006.0  ...      322.0  Nintendo       E
# 1  Super Mario Bros.      NES           1985.0  ...        NaN       NaN     NaN
# 2     Mario Kart Wii      Wii           2008.0  ...      709.0  Nintendo       E
#
# [3 rows x 16 columns]

# %%
games.shape
# Out:
# (16719, 16)

# %%
# Even from one glance you can see that there are many categorical type data which we will handle in Feature Engineering.

# %%
games.isnull().sum()
# Out:
# Name                  2
# Platform              0
# Year_of_Release     269
# Genre                 2
# Publisher            54
# NA_Sales              0
# EU_Sales              0
# JP_Sales              0
# Other_Sales           0
# Global_Sales          0
# Critic_Score       8582
# Critic_Count       8582
# User_Score         6704
# User_Count         9129
# Developer          6623
# Rating             6769
# dtype: int64

# %%
games['Rating'][1] == np.nan
# Out:
# False

# %%
# Since finding the sales (I am taking other_sales as I am Indian, you can take NA or Eu sales also) is the objective, for all the null 
# values in rating and user_score we are directly going to remove those rows.

games_filtered = games[games['Rating'].notna()]

games_filtered.isnull().sum()
# Out:
# Name                  0
# Platform              0
# Year_of_Release     181
# Genre                 0
# Publisher             7
# NA_Sales              0
# EU_Sales              0
# JP_Sales              0
# Other_Sales           0
# Global_Sales          0
# Critic_Score       1896
# Critic_Count       1896
# User_Score           71
# User_Count         2446
# Developer             0
# Rating                0
# dtype: int64

# %%
games_filtered.shape
# Out:
# (9950, 16)

# %%
games_filtered['Year_of_Release'].value_counts()
# Out:
# 2009.0    1011
# 2008.0     981
# 2007.0     821
# 2010.0     799
# 2005.0     706
# 2011.0     703
# 2006.0     678
# 2002.0     655
# 2003.0     613
# 2004.0     598
# 2012.0     355
# 2014.0     345
# 2001.0     339
# 2013.0     316
# 2015.0     315
# 2016.0     280
# 2000.0     148
# 1999.0      42
# 1998.0      32
# 1997.0      19
# 1996.0       7
# 1992.0       2
# 1988.0       1
# 1994.0       1
# 2020.0       1
# 1985.0       1
# Name: Year_of_Release, dtype: int64

# %%
games_filtered['Publisher'].value_counts()
# Out:
# Electronic Arts                 1139
# Ubisoft                          784
# Activision                       781
# THQ                              532
# Konami Digital Entertainment     382
#                                 ...
# Gameloft                           1
# White Park Bay Software            1
# NDA Productions                    1
# Valve                              1
# Arika                              1
# Name: Publisher, Length: 332, dtype: int64

# %%
games_filtered['User_Score'].value_counts()
# tbd is to be decided.
# Out:
# tbd    2375
# 7.8     322
# 8       286
# 8.2     278
# 8.5     252
#        ...
# 0.9       2
# 1.5       2
# 1         2
# 9.7       1
# 0         1
# Name: User_Score, Length: 96, dtype: int64

# %%
# Now for this project I will remove all null values but what you can do is fill some of them up apart those that I have and see if
# they help in getting more accuracy from the model that you build.

df1 = games_filtered[games_filtered['Critic_Score'].notna()]
df2 = df1[df1['Critic_Score'].notna()]
df3 = df2[df2['Critic_Count'].notna()]
df4 = df3[df3['User_Count'].notna()]

df4['Year_of_Release'].fillna(2009.0, inplace=True)
df4['Publisher'].fillna("Electronic Arts", inplace = True)
df4['User_Score'].fillna("tbd", inplace =True)

df4.isnull().sum()
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/series.py:4536: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   downcast=downcast,
# Name               0
# Platform           0
# Year_of_Release    0
# Genre              0
# Publisher          0
# NA_Sales           0
# EU_Sales           0
# JP_Sales           0
# Other_Sales        0
# Global_Sales       0
# Critic_Score       0
# Critic_Count       0
# User_Score         0
# User_Count         0
# Developer          0
# Rating             0
# dtype: int64

# %%
df4.shape
# Out:
# (6947, 16)

# %%
# Now if we were working on an industry level project, removing so many data-points won't be allowed. You will have to work more on the dataset.
# But for project level, we can do this as our main purpose in to understand and build a machine learning model not train a highly perceptive ml 
# model. This dataset can be a prime example of how in real life you will get your dataset; having lots of irregular and null values 
# which needs alot of preprocessing.

# %%
df4.describe()
# Out:
#        Year_of_Release     NA_Sales  ...  Critic_Count    User_Count
# count      6947.000000  6947.000000  ...   6947.000000   6947.000000
# mean       2007.464517     0.392840  ...     28.873615    173.821362
# std           4.179323     0.961157  ...     19.195731    584.511840
# min        1985.000000     0.000000  ...      3.000000      4.000000
# 25%        2004.000000     0.060000  ...     14.000000     11.000000
# 50%        2007.000000     0.150000  ...     24.000000     27.000000
# 75%        2010.000000     0.390000  ...     39.000000     88.000000
# max        2016.000000    41.360000  ...    113.000000  10665.000000
#
# [8 rows x 9 columns]

# %%
plt.figure(figsize=(8,8))
sns.heatmap(df4.corr(),annot=True,cmap='viridis',linewidths=.5)

# %%
# From the above visualization we can see some of the columns are very highly correlated to each other. So we are gonna drop those 
# specific columns

# %%
filtered_df = df4.drop(['Global_Sales'], axis=1)

filtered_df.head(3)
# Out:
#                 Name Platform  Year_of_Release  ... User_Count Developer  Rating
# 0         Wii Sports      Wii           2006.0  ...      322.0  Nintendo       E
# 2     Mario Kart Wii      Wii           2008.0  ...      709.0  Nintendo       E
# 3  Wii Sports Resort      Wii           2009.0  ...      192.0  Nintendo       E
#
# [3 rows x 15 columns]

# %%
# Finding categorical type data columns in our dataset.

filtered_df['Platform'].value_counts()
# Out:
# PS2     1161
# X360     877
# PS3      783
# PC       667
# XB       580
# Wii      491
# DS       468
# PSP      393
# GC       356
# GBA      241
# PS4      239
# XOne     159
# 3DS      157
# PS       153
# PSV      119
# WiiU      89
# DC        14
# Name: Platform, dtype: int64

# %%
# From all the above categories that we got, I am going to reduce the categories to only 5 values

def platform(x):
  if x == 'PS2':
    return 'PS2'
  elif x == 'X360':
    return 'X360'
  elif x == 'PS3':
    return 'PS3'
  elif x == 'PC':
    return 'PC'
  else:
    return 'other_console'

filtered_df['Platform_new'] = filtered_df['Platform'].map(platform)

filtered_df.head(1)
# Out:
#          Name Platform  Year_of_Release  ... Developer Rating   Platform_new
# 0  Wii Sports      Wii           2006.0  ...  Nintendo      E  other_console
#
# [1 rows x 16 columns]

# %%
filtered_df['Genre'].value_counts()
# Out:
# Action          1663
# Sports           965
# Shooter          882
# Role-Playing     718
# Racing           591
# Platform         407
# Misc             394
# Fighting         382
# Simulation       301
# Strategy         274
# Adventure        249
# Puzzle           121
# Name: Genre, dtype: int64

# %%
Developers_list = dict(filtered_df['Developer'].value_counts())

print(Developers_list)
# Out:
# {'EA Canada': 152, 'EA Sports': 145, 'Capcom': 128, 'Ubisoft': 104, 'Konami': 98, 'Ubisoft Montreal': 88, 'EA Tiburon': 86, 'Omega Force': 69, 'Visual Concepts': 68, 'Electronic Arts': 68, "Traveller's Tales": 68, 'Nintendo': 68, 'Vicarious Visions': 59, 'Codemasters': 58, 'Namco': 55, "Yuke's": 48, 'Midway': 44, 'TT Games': 43, 'Neversoft Entertainment': 43, 'Maxis': 42, 'Treyarch': 42, 'From Software': 41, 'Eurocom Entertainment Software': 40, 'Square Enix': 40, 'Sonic Team': 36, 'TOSE': 34, 'Radical Entertainment': 34, 'Artificial Mind and Movement': 32, 'Sega': 32, 'Harmonix Music Systems': 32, 'Arc System Works': 32, 'High Voltage Software': 31, 'Rebellion': 30, 'Koei': 27, 'Gearbox Software': 27, 'Climax Group': 26, 'Acclaim': 25, 'SCEA San Diego Studios': 25, 'KCET': 25, 'Rainbow Studios': 25, 'Criterion Games': 24, 'EA Games': 24, 'Krome Studios': 24, 'EA DICE': 24, 'Griptonite Games': 23, 'Ubisoft Shanghai': 23, 'CyberConnect2': 22, 'BioWare': 22, 'Exient Entertainment': 22, 'Nippon Ichi Software': 22, 'THQ': 21, 'EA Redwood Shores': 21, 'Crystal Dynamics': 21, 'Volition Inc.': 21, 'Terminal Reality': 21, 'LucasArts': 21, 'Team 17': 21, 'Dimps Corporation': 20, 'Blizzard Entertainment': 20, 'Creative Assembly': 20, 'Heavy Iron Studios': 20, 'EA Bright Light': 20, 'Techland': 20, 'Io Interactive': 20, 'Double Helix Games': 19, 'SNK Playmore': 19, 'Eutechnyx': 19, 'Beenox': 19, 'Milestone S.r.l': 19, 'Bandai Namco Games': 18, 'Kush Games': 18, 'WayForward': 18, 'Intelligent Systems': 18, 'Ubisoft Montpellier': 18, 'Amaze Entertainment': 18, 'SCE Japan Studio': 17, 'Rockstar San Diego': 17, 'Spike': 17, 'Tecmo': 17, 'Sumo Digital': 17, 'Toys for Bob': 17, 'PlatinumGames': 17, 'Blitz Games': 17, 'Atlus': 17, '3DO': 17, 'Team Ninja': 17, 'Backbone Entertainment': 16, 'Taito Corporation': 16, 'EA LA': 16, 'Avalanche Software': 16, 'Black Box': 16, 'Raven Software': 16, 'Obsidian Entertainment': 16, 'Pandemic Studios': 16, 'Rare Ltd.': 16, 'Digital Eclipse': 16, 'Level 5': 15, 'Infinity Ward': 15, 'Z-Axis, Ltd.': 15, 'PopCap': 15, 'SquareSoft': 15, 'Ubisoft Paris': 14, 'Relic': 14, 'Rockstar North': 14, 'Argonaut Games': 14, 'SCEA': 14, 'Point of View': 14, 'Next Level Games': 13, 'HAL Labs': 13, '2K Sports': 13, 'Gust': 13, 'Digital Illusions': 13, 'Visceral Games': 13, 'Mass Media': 13, 'n-Space': 13, 'Blue Castle Games': 13, 'Grasshopper Manufacture': 13, 'Namco Bandai Games': 13, 'Valve Software': 13, 'Firaxis Games': 13, 'FUN Labs': 13, 'Sting': 12, 'Cavia Inc.': 12, 'Vicious Cycle': 12, 'SCEE London Studio': 12, 'Kojima Productions': 12, '7 Studios': 12, 'HB Studios Multimedia': 12, '989 Sports': 12, 'Edge of Reality': 12, 'Blue Tongue Entertainment': 12, 'Game Arts': 12, 'Ubisoft Quebec': 12, 'Asobo Studio': 12, 'Neverland': 12, 'Activision': 12, 'Ubisoft Romania': 11, 'Microsoft Game Studios': 11, 'EA Black Box': 11, 'Paradigm Entertainment': 11, 'Bugbear': 11, 'Epic Games': 11, 'Haemimont': 11, 'Gaijin Entertainment': 11, 'High Moon Studios': 11, 'Bandai': 11, 'Racjin': 11, 'KCEJ': 11, 'Rocksteady Studios': 11, 'Acquire': 11, 'Hudson': 11, 'Free Radical Design': 11, 'Pipeworks Software, Inc.': 11, 'Tri-Ace': 11, 'Starbreeze': 11, 'Monolith Productions': 10, 'Bizarre Creations': 10, 'Crytek': 10, 'Treasure': 10, 'Acclaim Studios Cheltenham': 10, 'Shiny Entertainment': 10, 'Hudson Soft': 10, 'Naughty Dog': 10, 'FreeStyleGames': 10, 'Shaba Games': 10, 'Spark Unlimited': 10, 'Now Production': 10, 'Frontier Developments': 10, 'Natsume': 10, 'Spike Chunsoft': 10, 'Pivotal Games': 10, 'Digital Extremes': 9, 'Piranha Bytes': 9, 'Sega AM2': 9, 'Avalanche Studios': 9, '5TH Cell': 9, 'Bethesda Game Studios': 9, 'TT Fusion': 9, 'Day 1 Studios': 9, 'Compile Heart': 9, 'Image Epoch, Imageepoch': 9, 'Game Republic': 9, 'Rockstar Leeds': 9, 'Page 44 Studios': 9, 'Papaya Studios': 9, 'Camelot Software Planning': 9, 'Sports Interactive': 9, 'Kuju Entertainment': 9, 'InXile Entertainment': 9, 'Falcom': 9, 'Insomniac Games': 9, 'Stormf ...

# %%
# Doing the same as we did for Platform column, building only 3-4 categories for the Developer column.

def developer(x):
  if x.find('EA') >= 0 or x.find('Electronic Arts') >= 0:
    return 'EA'
  elif x.find('Capcom') >= 0:
    return 'Capcom'
  elif x.find('Ubisoft') >= 0:
    return 'Ubisoft'
  elif x.find('Konami') >= 0:
    return 'Komani'
  elif x.find('Nitendo') >= 0:
    return 'Nitendo'
  else:
    return 'other_dev'


filtered_df['Developer_new'] = filtered_df['Developer'].map(developer)

filtered_df.head(1)
# Out:
#          Name Platform  Year_of_Release  ... Rating   Platform_new  Developer_new
# 0  Wii Sports      Wii           2006.0  ...      E  other_console      other_dev
#
# [1 rows x 17 columns]

# %%
filtered_df['Rating'].value_counts()
# Out:
# T       2420
# E       2118
# M       1459
# E10+     946
# RP         2
# K-A        1
# AO         1
# Name: Rating, dtype: int64

# %%
def rating(x):
  if x == 'T':
    return 'T'
  elif x == 'E':
    return 'E'
  elif x == 'M':
    return 'M'
  elif x == 'E10+':
    return 'E10+'
  else:
    return 'other_rating'

filtered_df['Rating_new'] = filtered_df['Rating'].map(rating)

filtered_df.head(1)
# Out:
#          Name Platform  Year_of_Release  ...   Platform_new Developer_new  Rating_new
# 0  Wii Sports      Wii           2006.0  ...  other_console     other_dev           E
#
# [1 rows x 18 columns]

# %%
pub = dict(filtered_df['Publisher'].value_counts())

print(pub)
# Out:
# {'Electronic Arts': 960, 'Activision': 498, 'Ubisoft': 498, 'Sony Computer Entertainment': 316, 'THQ': 309, 'Nintendo': 292, 'Sega': 288, 'Take-Two Interactive': 274, 'Konami Digital Entertainment': 248, 'Namco Bandai Games': 241, 'Capcom': 200, 'Atari': 179, 'Microsoft Game Studios': 141, 'Warner Bros. Interactive Entertainment': 139, 'Tecmo Koei': 137, 'Square Enix': 135, 'Eidos Interactive': 125, 'Vivendi Games': 116, 'Codemasters': 113, 'Midway Games': 105, '505 Games': 80, 'Deep Silver': 77, 'Disney Interactive Studios': 75, 'LucasArts': 71, 'Unknown': 67, 'Acclaim Entertainment': 66, 'Nippon Ichi Software': 61, 'Rising Star Games': 52, 'Bethesda Softworks': 48, 'D3Publisher': 36, 'Focus Home Interactive': 31, 'Ignition Entertainment': 30, 'Empire Interactive': 28, 'Atlus': 25, 'Zoo Digital Publishing': 24, 'Kalypso Media': 24, 'Majesco Entertainment': 23, 'PQube': 22, 'SouthPeak Games': 21, 'TDK Mediactive': 21, 'Global Star': 20, 'Virgin Interactive': 19, 'Universal Interactive': 19, 'MTV Games': 17, 'Infogrames': 15, '3DO': 15, 'Paradox Interactive': 13, 'DTP Entertainment': 12, 'Ubisoft Annecy': 12, 'Sony Computer Entertainment Europe': 11, 'SCi': 11, 'Crave Entertainment': 11, 'Nordic Games': 10, 'BAM! Entertainment': 10, 'JoWood Productions': 10, 'Playlogic Game Factory': 10, 'Ghostlight': 10, 'Marvelous Interactive': 9, 'SquareSoft': 9, 'Play It': 9, 'Midas Interactive Entertainment': 8, 'Gathering of Developers': 8, 'Black Bean Games': 8, 'Metro 3D': 8, 'Idea Factory': 8, 'City Interactive': 8, 'Interplay': 8, 'Spike': 8, 'Sony Online Entertainment': 7, 'Kemco': 7, 'PopCap Games': 7, 'Jaleco': 7, 'Microids': 7, 'Sting': 6, 'GungHo': 6, 'Destineer': 6, 'DreamCatcher Interactive': 6, 'Aksys Games': 6, 'Activision Value': 6, 'Success': 5, 'Koch Media': 5, 'From Software': 5, 'Game Factory': 5, 'NCSoft': 5, 'Natsume': 5, 'Titus': 5, 'Arc System Works': 4, 'Yacht Club Games': 4, 'Milestone S.r.l': 4, 'Banpresto': 4, 'Hudson Soft': 4, 'Milestone S.r.l.': 4, 'Evolved Games': 4, 'Touchstone': 4, 'Marvelous Entertainment': 4, 'Gamecock': 4, 'Takara Tomy': 4, 'Xseed Games': 4, 'Telltale Games': 4, 'Tomy Corporation': 4, 'Screenlife': 4, 'Enix Corporation': 4, 'Compile Heart': 4, 'RedOctane': 4, 'Hip Interactive': 4, 'Sammy Corporation': 4, 'Bigben Interactive': 4, 'FuRyu': 3, 'Psygnosis': 3, 'The Adventure Company': 3, 'Swing! Entertainment': 3, 'Idea Factory International': 3, 'Little Orbit': 3, 'MC2 Entertainment': 3, 'Avalon Interactive': 3, 'Enterbrain': 3, 'Brash Entertainment': 3, 'Wanadoo': 3, 'System 3 Arcade Software': 3, 'Sony Computer Entertainment America': 3, 'Destination Software, Inc': 3, 'Zoo Games': 3, 'Genki': 3, 'GT Interactive': 3, 'Mastiff': 3, 'Insomniac Games': 3, 'Valve Software': 3, 'Falcom Corporation': 3, 'Rage Software': 3, 'Nobilis': 3, 'Slightly Mad Studios': 3, 'Mastertronic': 3, 'Taito': 3, 'Trion Worlds': 3, 'Indie Games': 3, 'Oxygen Interactive': 2, 'Agatsuma Entertainment': 2, 'Tripwire Interactive': 2, 'Gust': 2, 'Funcom': 2, 'Mad Catz': 2, 'Human Entertainment': 2, 'bitComposer Games': 2, 'Revolution Software': 2, 'CCP': 2, 'Valcon Games': 2, 'Xplosiv': 2, 'NovaLogic': 2, 'Mindscape': 2, 'Rondomedia': 2, 'XS Games': 2, 'AQ Interactive': 2, 'Gotham Games': 2, 'Harmonix Music Systems': 2, 'Jester Interactive': 2, 'Stainless Games': 2, 'Rebellion': 2, 'Square Enix ': 2, '1C Company': 2, 'Kadokawa Shoten': 2, 'Sold Out': 2, 'Ascaron Entertainment GmbH': 2, 'Tru Blu Entertainment': 2, 'Gamebridge': 2, 'Aspyr': 2, 'Irem Software Engineering': 2, 'Agetec': 2, 'Graffiti': 2, 'FuRyu Corporation': 1, 'Flashpoint Games': 1, 'Crimson Cow': 1, 'Phantom EFX': 1, 'inXile Entertainment': 1, 'Visco': 1, 'Max Five': 1, 'Just Flight': 1, 'Dusenberry Martin Racing': 1, 'HMH Interactive': 1, 'EA Games': 1, 'Monte Christo Multimedia': 1, 'Havas Interactive': 1, 'Illusion Softworks': 1, 'Sunflowers': 1, 'Home Entertainment Suppliers': 1, 'Cave': 1, 'TalonSoft': 1, 'Square EA': 1, 'Funsta': 1, 'Black Label Game ...

# %%
def publisher(x):
  if x == 'Electronic Arts':
    return 'Electronic Arts'
  elif x == 'Activision':
    return 'Activision'
  elif x == 'Ubisoft':
    return 'Ubisoft'
  elif x == 'Sony Computer Entertainment':
    return 'Sony Computer Entertainment'
  elif x == 'Nintendo':
    return 'Nintendo'
  elif x == 'Konami Digital Entertainment':
    return 'Konami Digital Entertainment'
  else:
    return 'other_publisher'

filtered_df['Publisher_new'] = filtered_df['Publisher'].map(publisher)

filtered_df.head(1)
# Out:
#          Name Platform  Year_of_Release  ... Developer_new Rating_new  Publisher_new
# 0  Wii Sports      Wii           2006.0  ...     other_dev          E       Nintendo
#
# [1 rows x 19 columns]

# %%
# Removing all unwanted columns from the dataset.

new_df = filtered_df.drop(['Platform', 'Genre', 'Publisher', 'User_Score', 'Developer', 'Rating', 'Name'], axis = 1)

new_df.head(2)
# Out:
#    Year_of_Release  NA_Sales  EU_Sales  ...  Developer_new  Rating_new  Publisher_new
# 0           2006.0     41.36     28.96  ...      other_dev           E       Nintendo
# 2           2008.0     15.68     12.76  ...      other_dev           E       Nintendo
#
# [2 rows x 12 columns]

# %%
y = new_df['Other_Sales']

plat_new = pd.get_dummies(new_df['Platform_new'])
dev_new = pd.get_dummies(new_df['Developer_new'])
rat_new = pd.get_dummies(new_df['Rating_new'])
pub_new = pd.get_dummies(new_df['Publisher_new'])

X_ = pd.concat([new_df, plat_new, dev_new, rat_new, pub_new], axis = 1)
X = X_.drop(['Other_Sales', 'Platform_new', 'Developer_new', 'Rating_new', 'Publisher_new'], axis = 1) 

X.head()
# Out:
#    Year_of_Release  NA_Sales  ...  Ubisoft  other_publisher
# 0           2006.0     41.36  ...        0                0
# 2           2008.0     15.68  ...        0                0
# 3           2009.0     15.61  ...        0                0
# 6           2006.0     11.28  ...        0                0
# 7           2006.0     13.96  ...        0                0
#
# [5 rows x 29 columns]

# %%
X.columns
# Out:
# Index(['Year_of_Release', 'NA_Sales', 'EU_Sales', 'JP_Sales', 'Critic_Score',
#        'Critic_Count', 'User_Count', 'PC', 'PS2', 'PS3', 'X360',
#        'other_console', 'Capcom', 'EA', 'Komani', 'Ubisoft', 'other_dev', 'E',
#        'E10+', 'M', 'T', 'other_rating', 'Activision', 'Electronic Arts',
#        'Konami Digital Entertainment', 'Nintendo',
#        'Sony Computer Entertainment', 'Ubisoft', 'other_publisher'],
#       dtype='object')

# %%
Xtrain, Xtest, ytrain, ytest = train_test_split(X, y, test_size=0.2)

# %%
reg = LinearRegression()
model1 = reg.fit(Xtrain, ytrain)

# %%
print(reg.score(Xtrain, ytrain))
# Out:
# 0.6385197427987714

# %%
# Predicting 
pred = reg.predict(Xtest)

r2_score = reg.score(Xtest,ytest)
print(r2_score)
# Out:
# 0.40995264734549997

# %%
# Save the trained model as a pickle string.
import pickle

saved_model = pickle.dump(reg, open('drive/MyDrive/Dataset/Models/VideoGamesModel.pickle','wb'))
  
# Load the pickled model - reg_from_pickle = pickle.load(saved_model)
# Use the loaded pickled model to make predictions - reg_from_pickle.predict(X_test)
